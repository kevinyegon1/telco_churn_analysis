# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
churn = pd.read_csv(r"C:\Users\hi\Desktop\Data Analytics\Data Sets\Old\Telco_Cusomer_Churn.csv")
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
categotric_features = churn.select_dtypes('object','category').columns
numerical_features = churn.select_dtypes('int64','float64').columns

# %%
#scaler.fit_transform(numerical_features)

# %%
from sklearn.preprocessing import StandardScaler

# %%
churn.select_dtypes('int64','float64').columns
# Out:
# Index(['SeniorCitizen', 'tenure'], dtype='object')

# %%
churn.select_dtypes('int64','float64').columns
# Out:
# Index(['SeniorCitizen', 'tenure'], dtype='object')

# %%
churn['SeniorCitizen'] = pd.to_numeric(churn.SeniorCitizen)
churn['SeniorCitizen'] = churn.SeniorCitizen.fillna(0).astype('int')

# %%
churn['TotalCharges'] = pd.to_numeric(churn.TotalCharges, errors='coerce')
churn['TotalCharges'] = churn.TotalCharges.fillna(0)
churn.TotalCharges.isna().sum()
# Out:
# np.int64(0)

# %%
num_features = ['SeniorCitizen', 'tenure','TotalCharges']
churn[num_features]
# Out:
#       SeniorCitizen  tenure  TotalCharges
# 0                 0       1         29.85
# 1                 0      34       1889.50
# 2                 0       2        108.15
# 3                 0      45       1840.75
# 4                 0       2        151.65
# ...             ...     ...           ...
# 7038              0      24       1990.50
# 7039              0      72       7362.90
# 7040              0      11        346.45
# 7041              1       4        306.60
# 7042              0      66       6844.50
#
# [7043 rows x 3 columns]

# %%
scaler = StandardScaler()
churn[num_features] = scaler.fit_transform(churn[num_features])

# %%
churn[num_features]
# Out:
#       SeniorCitizen    tenure  TotalCharges
# 0         -0.439916 -1.277445     -0.992611
# 1         -0.439916  0.066327     -0.172165
# 2         -0.439916 -1.236724     -0.958066
# 3         -0.439916  0.514251     -0.193672
# 4         -0.439916 -1.236724     -0.938874
# ...             ...       ...           ...
# 7038      -0.439916 -0.340876     -0.127605
# 7039      -0.439916  1.613701      2.242606
# 7040      -0.439916 -0.870241     -0.852932
# 7041       2.273159 -1.155283     -0.870513
# 7042      -0.439916  1.369379      2.013897
#
# [7043 rows x 3 columns]

# %%
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0  7590-VHVEG  Female      -0.439916     Yes         No -1.277445
# 1  5575-GNVDE    Male      -0.439916      No         No  0.066327
# 2  3668-QPYBK    Male      -0.439916      No         No -1.236724
# 3  7795-CFOCW    Male      -0.439916      No         No  0.514251
# 4  9237-HQITU  Female      -0.439916      No         No -1.236724
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
churn.select_dtypes('object').columns
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
cat = ['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
       'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
       'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
       'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
       'Churn']

# %%
churn[cat] = churn[cat].astype('str')
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#STANDARDIZE STRINGS & TEXT
# Remove whitespace and ensure consistent casing for categorical columns
churn[cat] = churn[cat].apply(lambda x: x.str.strip().str.lower())
churn[cat]
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 0     7590-vhveg  female     yes         no           no  no phone service
# 1     5575-gnvde    male      no         no          yes                no
# 2     3668-qpybk    male      no         no          yes                no
# 3     7795-cfocw    male      no         no           no  no phone service
# 4     9237-hqitu  female      no         no          yes                no
# ...          ...     ...     ...        ...          ...               ...
# 7038  6840-resvb    male     yes        yes          yes               yes
# 7039  2234-xaduh  female     yes        yes          yes               yes
# 7040  4801-jzazl  female     yes        yes           no  no phone service
# 7041  8361-ltmkd    male     yes         no          yes               yes
# 7042  3186-ajiek    male      no         no          yes                no
#
# ...

# %%
churn['MultipleLines'] = churn.MultipleLines.map({'no phone service': 'no'})

# %%
#churn[churn[cat].isin(['yes', 'no'])]
yes_no_col = ['Partner','Dependents','PhoneService','','']
#churn[cat] = churn[cat].apply(lambda x: x.map({'yes':1, 'no':0}))

# %%
#churn.sample(50)

# %%
# cat
# churn = pd.get_dummies(churn, columns=cat)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
encoder.fit_transform(churn[cat])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 126774 stored elements and shape (7043, 13616)>

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     682 non-null    object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
churn ['Churn'] =  churn.Churn.map({'no':0, 'yes':1})
churn.Churn.unique()
# Out:
# array([0, 1])

# %%
y = churn['Churn']
X = churn.drop(columns=['customerID','Churn','MultipleLines'])

# %%
X.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges'],
#       dtype='object')

# %%
cat_feat = X.select_dtypes('object').columns
num_feat = X.select_dtypes('float64').columns

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
preprocessing_1 = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', num_feat),
        ('cat',OneHotEncoder(handle_unknown='ignore'), cat_feat) 
    ]
)

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.pipeline import make_pipeline

# # Create a pipeline that scales the data before running the model
# pipeline = make_pipeline(StandardScaler(), LogisticRegression())
# pipeline.fit(X_train, y_train)

# %%
#model using LogisticRegression

from sklearn.linear_model import LogisticRegression
#model = LogisticRegression(max_iter=1000)

model_1 = Pipeline(
    steps=[
    ('preprocessor',preprocessing ),
        ('predictor',LogisticRegression(max_iter=2000))
    ]
)

model_1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'TotalCharges'],
#       dtype='object'))])),
#                 ('predictor', LogisticRegression(max_iter=2000))])

# %%
y_pred = model_1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 1. Print simple accuracy
print(f"Accuracy Score: {accuracy_score(y_test, y_pred):.2f}")

# 2. Print the detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87      1047
#            1       0.63      0.57      0.60       362
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.73      0.74      1409
# weighted avg       0.80      0.80      0.80      1409

# %%
# print(X_train.columns.tolist())
# print(X_test.columns.tolist())

# %%
#model using Random Forest

from sklearn.ensemble import RandomForestClassifier
RandomForestClassifier(n_estimators=200, random_state=42)

preprocessing_2 = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_feat),
        ('cat',OneHotEncoder(handle_unknown='ignore'), cat_feat) 
    ]
)

model_2 = Pipeline(
    steps=[
        ('preprocessing',preprocessing_2),
        ('classifier',RandomForestClassifier(n_estimators=200, random_state=42) )
    ]
)
model_2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'TotalCharges'],
#       dtype='object'))])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %%
y_pred_2 = model_2.predict(X_test)

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 1. Print simple accuracy
print(f"Accuracy Score: {accuracy_score(y_test, y_pred_2):.2f}")

# 2. Print the detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_2))
# Out:
# Accuracy Score: 0.79
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1047
#            1       0.61      0.48      0.54       362
#
#     accuracy                           0.79      1409
#    macro avg       0.72      0.69      0.70      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
#modelling using xgboost
from sklearn.ensemble import GradientBoostingClassifier
#XGBClassifier(use_label_encoder=False, eval_metric='logloss')

preprocessing_3 = ColumnTransformer(
    transformers=[
        ('num',StandardScaler(), num_feat),
        ('cat',OneHotEncoder(handle_unknown='ignore'),cat_feat)
    ]
)

model_3 = Pipeline(
    steps=[
        ('preprocessing', preprocessing_3),
        ('classifier', GradientBoostingClassifier())
    ]
)
model_3.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'TotalCharges'],
#       dtype='object'))])),
#                 ('classifier', GradientBoostingClassifier())])

# %%
y_pred_3 = model_3.predict(X_test)

# 1. Print simple accuracy
print(f"Accuracy Score: {accuracy_score(y_test, y_pred_3):.2f}")

# 2. Print the detailed report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_3))
# Out:
# Accuracy Score: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1047
#            1       0.65      0.52      0.58       362
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.79      0.80      0.80      1409
